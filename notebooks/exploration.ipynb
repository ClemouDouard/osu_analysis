# %% [markdown]
# # First exploration of the dataset
#
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/raw/metadata.csv', index_col='beatmapset_id')

# %% [markdown]
# ## Exploration

# %%
df.head()
# Out:
#                                      Unnamed: 0  split  \
# beatmapset_id
# 35233          0000e4db9a35c1e567265d350c299569  train
# 830266         00010f0eb02ee131aacac54bf72d5444  train
# 881569         0001599a2547ff2113753923d9bb93f6  train
# 658811         0002d54f1de47dbcd242ff3dd2e24274  valid
# 56940          00034f3ca36bb76bb69e30c276726221  valid
#
#                                      audio_hash  beatmap_id  approved  \
# beatmapset_id
# 35233          b06a550c393d8a72441932508595bf4e      120019         1
# 830266         5bea04ca275826768fa4f8411822c388     1739583         1
# 881569         f1a3190966c37d8aa83fe540f12e43f2     1844646         1
# 658811         d8702cabd065196cead6742827050265     1395349         1
# 56940          19f71684a3c9a710594c7e927345c11d      175250         1
#
#                total_length  hit_length         version  \
# beatmapset_id
# 35233                   102          88     Zelos' Hard
# 830266                  221         215     Zero Vector
# 881569                   96          95   Poii's Futsuu
# 658811                  380         368   Virtual Beach
# 56940                    87          81  Quilt's Insane
#
#                                        file_md5  diff_size  ...  video  \
# beatmapset_id                                               ...
# 35233          0000e4db9a35c1e567265d350c299569        4.0  ...      0
# 830266         00010f0eb02ee131aacac54bf72d5444        5.0  ...      0
# 881569         0001599a2547ff2113753923d9bb93f6        2.0  ...      0
# 658811         0002d54f1de47dbcd242ff3dd2e24274        3.0  ...      0
# 56940          00034f3ca36bb76bb69e30c276726221        4.0  ...      1
#
#                download_unavailable  audio_unavailable  playcount  passcount  \
# beatmapset_id
# 35233                             0                  0      40780      16453
# 830266                            0                  0      37233       4581
# 881569                            0                  0       1036        530
# 658811                            0                  0      36207       3213
# 56940                             0                  0     622464      86133
#
#                       packs  max_combo diff_aim diff_speed difficultyrating
# beatmapset_id
# 35233          R38,R39,S203      297.0  1.38127    1.27099          2.70740
# 830266                 S757      939.0  2.49147    2.39868          4.93655
# 881569                 ST50      194.0      NaN        NaN          1.93105
# 658811                 S624     1394.0  1.85486    1.65950          3.61204
# 56940                  S310      403.0  2.01999    1.84677          3.95337
#
# [5 rows x 44 columns]

# %%
df.shape
# Out:
# (107977, 44)

# %%
df.dtypes
# Out:
# Unnamed: 0               object
# split                    object
# audio_hash               object
# beatmap_id                int64
# approved                  int64
# total_length              int64
# hit_length                int64
# version                  object
# file_md5                 object
# diff_size               float64
# diff_overall            float64
# diff_approach           float64
# diff_drain              float64
# mode                      int64
# count_normal              int64
# count_slider              int64
# count_spinner             int64
# submit_date              object
# approved_date            object
# last_update              object
# artist                   object
# artist_unicode           object
# title                    object
# title_unicode            object
# creator                  object
# creator_id                int64
# bpm                     float64
# source                   object
# tags                     object
# genre_id                  int64
# language_id               int64
# favourite_count           int64
# rating                  float64
# storyboard                int64
# video                     int64
# download_unavailable      int64
# audio_unavailable         int64
# playcount                 int64
# passcount                 int64
# packs                    object
# max_combo               float64
# diff_aim                float64
# diff_speed              float64
# difficultyrating        float64
# dtype: object

# %%
df['source']
# Out:
# beatmapset_id
# 35233                                  NaN
# 830266                                凹凸世界
# 881569                  C.D.Christmas Days
# 658811                                 NaN
# 56940                      Little Busters!
#                         ...
# 529724                                 NaN
# 847800                        Clover Day's
# 1236029                             Lanota
# 859022     Tomba! 2: The Evil Swine Return
# 434391                                 NaN
# Name: source, Length: 107977, dtype: object

# %% [markdown]
# ## Remove some attributes

# %%
cols_to_drop = ['split', 'Unnamed: 0', 'audio_hash', 'file_md5', 'beatmap_id', 'source', 'tags']

df.drop(cols_to_drop, axis=1, inplace=True)

# %%
df.describe()
# Out:
#             approved   total_length     hit_length      diff_size  \
# count  107977.000000  107977.000000  107977.000000  107977.000000
# mean        1.004297     146.790687     136.268696       3.871712
# std         0.065412      80.414822      74.199253       0.952439
# min         1.000000      12.000000      11.000000       0.000000
# 25%         1.000000      89.000000      87.000000       3.200000
# 50%         1.000000     120.000000     113.000000       4.000000
# 75%         1.000000     197.000000     176.000000       4.000000
# max         2.000000    3178.000000    2706.000000      10.000000
#
#         diff_overall  diff_approach     diff_drain           mode  \
# count  107977.000000  107977.000000  107977.000000  107977.000000
# mean        5.924872       6.696688       5.137913       0.421192
# std         2.112007       2.270757       1.687726       0.854656
# min         0.000000       0.000000       0.000000       0.000000
# 25%         4.000000       5.000000       4.000000       0.000000
# 50%         6.000000       7.000000       5.000000       0.000000
# 75%         8.000000       9.000000       6.000000       0.000000
# max        10.000000      10.000000      10.000000       3.000000
#
#         count_normal   count_slider  ...     storyboard          video  \
# count  107977.000000  107977.000000  ...  107977.000000  107977.000000
# mean      324.846810     144.882577  ...       0.155561       0.247692
# std       439.251711     143.901190  ...       0.362440       0.431674
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%        92.000000      53.000000  ...       0.000000       0.000000
# 50%       190.000000     113.000000  ...       0.000000       0.000000
# 75%       384.000000     189.000000  ...       0.000000       0.000000
# max     13183.000000    3674.000000  ...       1.000000       1.000000
#
#        download_unavailable  audio_unavailable     playcount     passcount  \
# count              107977.0           107977.0  1.079770e+05  1.079770e+05
# mean                    0.0                0.0  1.667828e+05  3.809445e+04
# std                     0.0                0.0  5.503267e+05  1.278616e+05
# min                     0.0                0.0  5.800000e+01  5.000000e+00
# 25%                     0.0                0.0  1.699200e+04  4.100000e+03
# 50%                     0.0                0.0  4.598100e+04  1.163300e+04
# 75%                     0.0                0.0  1.288800e+05  3.160300e+04
# max                     0.0                0.0  3.022019e+07  1.060358e+07
#
#            max_combo      diff_aim    diff_speed  difficultyrating
# count  100799.000000  86332.000000  81593.000000     107977.000000
# mean      621.582704      1.845419      1.602199          3.434154
# std       496.400555      0.888734      0.654841          1.436405
# min         7.000000      0.231951      0.186188          0.339573
# 25%       315.000000      1.114857      1.011380          2.163300
# 50%       485.000000      1.711490      1.593940          3.329430
# 75%       764.000000      2.385430      2.107820          4.512550
# max     13021.000000      9.347180      5.804670         11.286500
#
# [8 rows x 27 columns]

# %%
df.isnull().sum()
# Out:
# approved                    0
# total_length                0
# hit_length                  0
# version                     2
# diff_size                   0
# diff_overall                0
# diff_approach               0
# diff_drain                  0
# mode                        0
# count_normal                0
# count_slider                0
# count_spinner               0
# submit_date                 0
# approved_date               0
# last_update                 0
# artist                     49
# title                       1
# creator                     0
# creator_id                  0
# bpm                         0
# genre_id                    0
# language_id                 0
# favourite_count             0
# rating                      0
# storyboard                  0
# video                       0
# download_unavailable        0
# audio_unavailable           0
# playcount                   0
# passcount                   0
# packs                    1282
# max_combo                7178
# diff_aim                21645
# diff_speed              26384
# difficultyrating            0
# dtype: int64

# %%
df.drop(['artist_unicode', 'title_unicode'], axis=1, inplace=True)
